# %%
import zipfile
#fantasy_zip = zipfile.ZipFile('/notebooks/HJS/AdaIn_2/AdaIN/input/WHOLE_1.zip')
#fantasy_zip.extractall('/notebooks/HJS/AdaIn_2/AdaIN/input/WHOLE/')

# %%
def unzip(source_file, dest_path):
    with zipfile.ZipFile(source_file, 'r') as zf:
        zipInfo = zf.infolist()
        for member in zipInfo:
            try:
                print(member.filename.encode('cp437').decode('euc-kr', 'ignore'))
                member.filename = member.filename.encode('cp437').decode('euc-kr', 'ignore')
                zf.extract(member, dest_path)
            except:
                print(source_file)
                raise Exception('what?!')

# %%
unzip('/notebooks/HJS/AdaIn_3/input/김홍도.zip','/notebooks/HJS/AdaIn_3/input/김홍도/' )
# Out:
# k10.JPG
# k100.JPG
# k101.JPG
# k102.JPG
# k103.JPG
# k104.JPG
# k105.JPG
# k106.JPG
# k107.JPG
# k108.JPG
# k109.JPG
# k11.JPG
# k110.JPG
# k111.JPG
# k112.JPG
# k113.JPG
# k114.JPG
# k115.JPG
# k116.JPG
# k117.JPG
# k118.JPG
# k12.JPG
# k120.JPG
# k121.JPG
# k122.JPG
# k124.JPG
# k125.JPG
# k126.JPG
# k127.JPG
# k128.JPG
# k129.JPG
# k13.JPG
# k130.JPG
# k131.JPG
# k132.JPG
# k133.JPG
# k134.JPG
# k136.JPG
# k137.JPG
# k138.JPG
# k14.JPG
# k140.JPG
# k141.JPG
# k142.JPG
# k143.JPG
# k144.JPG
# k146.JPG
# k147.JPG
# k148.JPG
# k149.JPG
# k15.JPG
# k150.JPG
# k152.JPG
# k153.JPG
# k154.JPG
# k155.JPG
# k156.JPG
# k157.JPG
# k158.JPG
# k159.JPG
# k16.JPG
# k160.JPG
# k161.JPG
# k162.JPG
# k163.JPG
# k164.JPG
# k165.JPG
# k166.JPG
# k167.JPG
# k168.JPG
# k169.JPG
# k17.JPG
# k170.JPG
# k171.JPG
# k172.JPG
# k173.JPG
# k174.JPG
# k175.JPG
# k176.JPG
# k177.JPG
# k178.JPG
# k179.JPG
# k18.JPG
# k180.JPG
# k181.JPG
# k182.JPG
# k183.JPG
# k184.JPG
# k185.JPG
# k186.JPG
# k187.JPG
# ...

# %%
# !nvidia-smi
# Out:
# Thu Jan 14 08:28:42 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.100      Driver Version: 440.100      CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  TITAN RTX           Off  | 00000000:19:00.0 Off |                  N/A |
# | 41%   36C    P8    13W / 280W |   2189MiB / 24220MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  TITAN RTX           Off  | 00000000:1A:00.0 Off |                  N/A |
# | 41%   37C    P8    15W / 280W |   1691MiB / 24220MiB |      0%      Default |
# ...
